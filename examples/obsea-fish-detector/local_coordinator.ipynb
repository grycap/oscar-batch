# %%
from minio import Minio
from minio.error import S3Error
import math
import requests
from requests.auth import HTTPBasicAuth
import json
import zipfile
import time
import os
# Definition of necessary functions

def get_token(text):
    browser=['token":"','","file_stage_in']
    pos=[]
    for n in browser:
        k =text.find(n)
        if k!=-1:
            pos.append(k)
        else:
            break
    if k==-1:
        print('Error in connection')
        return None
    else:
        return text[pos[0]+8:pos[1]]

def get_cpuService(text):
    browser=['cpu":"','","total_memory']
    pos=[]
    for n in browser:
        k=text.find(n)
        if k!=-1:
            pos.append(k)
        else:
            break
    if k==-1:
        print('Error in connection')
        return None
    else:
        return 1000*float(text[pos[0]+6:pos[1]])

def get_memoryService(text):
    browser=['memory":"','Gi']
    pos=[]
    for n in browser:
        k=text.find(n)
        if k!=-1:
            pos.append(k)
        else:
            break
    if k==-1:
        print('Error in connection')
        return None
    else:
        return (float(text[pos[0]+9:pos[1]]))

def connect_to_minio(config):
    MinIO_url = config['url']
    MinIO_access_key = config['access_key']
    MinIO_secret_key = config['secret_key']
    #print(f"Connecting to MinIO at {url_minio} with access key {access_key}")
    return MinIO_url,MinIO_access_key,MinIO_secret_key 

def use_bucket(config):
    bucket_name = config['name']
    folder_prefix = config['folder_prefix']
    #print(f"Using bucket {bucket_name} with folder prefix {folder_prefix}")
    return bucket_name, folder_prefix

def setup_output(config):
    output_file = config['file']
    return output_file

def use_service(config):
    service_name = config['name']
    return service_name

def connect_to_oscar_cluster(config):
    token_cluster=''
    oscar_cluster= config['url']
    if 'username' in config_data.get('oscar_cluster', {}).get('auth_basic', {}):
        username = config['auth_basic']['username']
    if 'password' in config_data.get('oscar_cluster', {}).get('auth_basic', {}):
        password = config['auth_basic']['password']
    if username !="" and password != "":
        basic= True 
    else:
        if 'token' in config_data.get('oscar_cluster', {}).get('auth_token', {}):
            token_cluster = config['auth_token']['token']
            if token_cluster !='':
                basic=False
             
    return oscar_cluster,username,password,token_cluster,basic
def use_directory(config):
    directory=config['local'].get('folder')
    return directory

def list_directory(directory_path, output_file):
    try:
        # Get the list of files in the directory
        files = os.listdir(directory_path)
        
        # Filter the images with .jpg extension
        images = [file for file in files if file.lower().endswith('.jpg')]
        
        # Display the number of images
        print(f"Found {len(images)} images in the directory '{directory_path}'.")
        
        # Save the names of the images to a text file
        with open(output_file, 'w') as file:
            file.write('\n'.join(images))
        
        print(f"The names of the images have been saved to '{output_file}'.")
    except Exception as e:
        print(f"Error: {e}")
    return len(images), images

# %%
with open('config-walton-direct.json', 'r') as config_file:
    config_data = json.load(config_file)


# Take configuration values
MinIO_url,MinIO_access_key,MinIO_secret_key = connect_to_minio(config_data['MinIO'])
bucket_name, folder_prefix = use_bucket(config_data['bucket'])
output_file=setup_output(config_data['output'])
service_name=use_service(config_data['service'])
oscar_cluster, username, password,token_cluster, basic = connect_to_oscar_cluster(config_data['oscar_cluster'])

#List the directory where the images are located
directory_path = use_directory(config_data)
output_txt = directory_path+"/index.txt"          
num_imag,object_list=list_directory(directory_path, output_txt)
# Out:
# Found 15030 images in the directory 'fish'.
# The names of the images have been saved to 'fish/index.txt'.

# %%
service_info = "https://" + oscar_cluster + "/system/services/" + service_name
print(service_info)
 
# GET request via basic authentication or token
if basic:
    response = requests.get(service_info, auth=HTTPBasicAuth(username, password),verify=True)
else:
    headers = {
    'Authorization': "Bearer " + token_cluster
    }
    response = requests.get(service_info, headers=headers,verify=True)
 
# Check the status of the response
if response.status_code == 200:
    resp = response.text
    print(resp)
    # Calculate CPU, Memory and token of the service
    cpu_service = get_cpuService(resp)
    memory_service = get_memoryService(resp)
    print(cpu_service)
    print(memory_service)
    token_service = get_token(resp)
else:
    print(f"Request error: {response.status_code}")
    print("Error message:")
    print(response.text)
# Out:
# https://inference-walton.cloud.imagine-ai.eu/system/services/fish-detector-zip-3
# {"name":"fish-detector-zip-3","cluster_id":"","memory":"3Gi","cpu":"1.0","total_memory":"","total_cpu":"","enable_gpu":false,"enable_sgx":false,"image_prefetch":false,"synchronous":{"min_scale":0,"max_scale":0},"delegation":"","rescheduler_threshold":0,"log_level":"DEBUG","image":"dialdroid/fish-detector:zip-2","alpine":false,"token":"3ec1897407976c07e837e0b8f8ab7d3a552f590fe5f283183409cc4ce5c51f90","file_stage_in":false,"input":[],"output":[{"storage_provider":"minio.default","path":"fish-detector-output/output"}],"script":"#!/bin/sh\n\nOUTPUT_FILE=\"$TMP_OUTPUT_DIR/$FILE_NAME\"\nJSON=$(cat \"$INPUT_FILE_PATH\")\necho $JSON\n\nZIP_FILE=$(echo \"$JSON\" | jq -r '.zip')\n\npython3 fish_detector.py -i \"$BUCKET_DIR/$ZIP_FILE\" -o \"$OUTPUT_FILE\"\n\necho  $?","expose":{"min_scale":0,"max_scale":0,"cpu_threshold":0,"rewrite_target":false,"nodePort":0,"default_command":false,"set_auth":false},"environment":{"Variables":{"BUCKET_DIR":"/mnt/fish-detector/zip"}},"annotations":{},"vo":"vo.imagine-ai.eu","labels":{"applicationId":"fish-detector-zip-3","oscar_service":"fish-detector-zip-3","queue":"root.oscar-queue.fish-detector-zip-3","vo":"vo.imagine-ai.eu"},"storage_providers":{"minio":{"default":{"endpoint":"https://minio.gracious-varahamihira6.im.grycap.net","verify":false,"access_key":"minio","secret_key":"MinIOImag1ne","region":"us-east-1"}}},"owner":"634476eccf0d890dd6d909761baf374852cf50a20474ee2feade49549996d01f@egi.eu","interlink_node_name":"","allowed_users":[],"isolation_level":"","bucket_list":[],"mount":{"storage_provider":"minio.default","path":"/fish-detector/zip"}}
# 1000.0
# 3.0

# %%
# Initialize CPU and Memory allocation variables
cpu_Alloc=0
cpu_invoke=0
memory_Alloc=0
memory_invoke=0

# Ensure the URL is properly constructed (if `oscar_cluster` does not have "https://")
if not oscar_cluster.startswith("https://"):
    url_status = "https://" + oscar_cluster + "/system/status"
else:
    url_status = oscar_cluster + "/system/status"

# Make the GET request with basic authentication or token authentication
try:
    if basic:
        # Use basic authentication if enabled
        response = requests.get(url_status, auth=HTTPBasicAuth(username, password), verify=False)
    else:
        # Use token authentication if enabled
        headers = {
            'Authorization': "Bearer " + token_cluster
        }
        response = requests.get(url_status, headers=headers, verify=True)

    # Check the status of the response
    if response.status_code == 200:
        # Convert the response to JSON
        try:
            data = response.json()

            # Ensure the response is a dict object
            if isinstance(data, dict):
                nodos = len(data['detail'])
                data = data['detail']
                
                # Iterate over each object in the array, except the front node
                if nodos >= 1:
                    for obj in data:
                        cpu_Alloc=(int(obj['cpuCapacity']))*0.8 - int(obj['cpuUsage'])
                        cpu_invoke += int((cpu_Alloc/cpu_service))
                        memory_Alloc=(int(obj['memoryCapacity'])*0.8) - int(obj['memoryUsage'])
                        memory_invoke += int((memory_Alloc/(1000000000*memory_service)))
            else:
                print("The response is not a JSON array of objects.")
        
        except ValueError as e:
            print("Error converting the response to JSON:", e)
    else:
        print(f"Request error: {response.status_code}")
        print("Error message:")
        print(response.text)

except requests.exceptions.RequestException as e:
    print(f"Connection error: {e}")

print(f"CPU invocations: {cpu_invoke}")
print(f"Memory invocations: {memory_invoke}")
# Out:
# CPU invocations: 38
# Memory invocations: 36

# %%
# Search for the CPU needed to run the service defined in its creation (FDL)
if not oscar_cluster.startswith("https://"):
    service_info = "https://" + oscar_cluster + "/system/services/" + service_name
else:
    service_info = oscar_cluster + "/system/services/" + service_name
    
# GET request via basic authentication or token
if basic:
    response = requests.get(service_info, auth=HTTPBasicAuth(username, password),verify=True)
else:
    response = requests.get(service_info, headers=headers,verify=True)

# Check the status of the response
if response.status_code == 200:
    resp = response.text
    # Calculate CPU, Memory and token of the service
    cpu_service = get_cpuService(resp)
    memory_service = get_memoryService(resp)  # take 80% of the memory so as not to completely saturate the cluster
    token_service = get_token(resp)
else:
    print(f"Request error: {response.status_code}")
    print("Error message:")
    print(response.text)

# Min value between invocations by CPU and by memory
cant_invoke = min(cpu_invoke, memory_invoke)
print(f"Invocations: {cant_invoke}")

# Calculate the number of images per invocationç
#num_imag=108
resto = (num_imag) % cant_invoke
img_invoke = int(num_imag / cant_invoke)
print(f"Images per invocation: {img_invoke}")
# Out:
# Invocations: 36
# Images per invocation: 3

# %%
output_bucket = bucket_name

if basic:
    headers = {    
    'Authorization': "Bearer " + token_service,
    'Content-Type': 'application/json',
}
else:
    headers = {
    'Authorization': "Bearer " + token_cluster,
    'Content-Type': 'application/json',
    }

    
     # Configure the MinIO client
client = Minio(
    MinIO_url,  # MinIO server
    access_key=MinIO_access_key,  
    secret_key=MinIO_secret_key,  
    secure=True  
    )
# Ensure the URL is properly constructed (if `oscar_cluster` does not have "https://")
if not oscar_cluster.startswith("https://"):
    url_invoke = "https://" + oscar_cluster + "/job/" + service_name
else:
    url_invoke = oscar_cluster + "/job/" + service_name

end=0
start=0
# Range of images to process (start-end)
t1=time.time()
for i in range(cant_invoke):
    
    t=time.time()
    # Range of images
    start = end+1
    end = end+ img_invoke
    if i < resto:
        end = end+1
    name_zip=str(i+1)+".zip"

    data = {
        "zip": name_zip
        
    }
    print(data)
    
    #Create .zip
    list=object_list[int(start)-1:int(end)]
    zip_file_name = str(i+1)+".zip"
    output_path = "zip/" + name_zip
    print(name_zip)
    local_files=[]
    
    try:
       
        with zipfile.ZipFile(zip_file_name, 'w') as file_zip:
            # Iterate through the files in the directory
            for file in list:
                # Check if it is an image with .jpg extension
                if file.lower().endswith('.jpg'):
                    full_path = os.path.join(directory_path, file)
                    
                    # Add the image to the ZIP
                    file_zip.write(full_path, file)
                    
        
        print(f"ZIP file successfully created: {zip_file_name}")

    # Subir el archivo .zip al bucket de destino
        client.fput_object(
            output_bucket, 
            output_path,
            zip_file_name
          )
   # client.fput_object(output_bucket, zip_file_name, zip_file_name)
        print(f"{name_zip} successfully uploaded to the bucket {output_bucket}")
    
    finally:
      
   # Clean up temporary files
        for file in local_files:
            if os.path.exists(file):
                os.remove(file)
        if os.path.exists(zip_file_name):
                os.remove(zip_file_name)
    
    print(f"Start value: {start}")
    print(f"End value: {end}")
    print(f"Invocation {i + 1} to the service")
    print(url_invoke)
    
    # time between invocations
    time.sleep(5)
   
    output_path = folder_prefix + output_file
    
   
    try:
        response = requests.post(url_invoke, headers=headers, json=data,verify=True)
        if response.status_code == 200 or response.status_code == 201:
            print("Services OK")
        else:
            print(response.text)
    except Exception as ex:
        print("Error running service: ", ex)
        print(response.text)

    t2=time.time()
    print(f"Total time of service launch: {round(t2-t1,2)} seconds")
    
t=time.time()
print(f"Total time of the execution process: {round(t-t1,2)} seconds")
# Out:
# {'zip': '1.zip'}
# 1.zip
# ZIP file successfully created: 1.zip
# 1.zip successfully uploaded to the bucket fish-detector
# Start value: 1
# End value: 3
# Invocation 1 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.4 seconds
# {'zip': '2.zip'}
# 2.zip
# ZIP file successfully created: 2.zip
# 2.zip successfully uploaded to the bucket fish-detector
# Start value: 4
# End value: 6
# Invocation 2 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.25 seconds
# {'zip': '3.zip'}
# 3.zip
# ZIP file successfully created: 3.zip
# 3.zip successfully uploaded to the bucket fish-detector
# Start value: 7
# End value: 9
# Invocation 3 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '4.zip'}
# 4.zip
# ZIP file successfully created: 4.zip
# 4.zip successfully uploaded to the bucket fish-detector
# Start value: 10
# End value: 12
# Invocation 4 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.45 seconds
# {'zip': '5.zip'}
# 5.zip
# ZIP file successfully created: 5.zip
# 5.zip successfully uploaded to the bucket fish-detector
# Start value: 13
# End value: 15
# Invocation 5 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.04 seconds
# {'zip': '6.zip'}
# 6.zip
# ZIP file successfully created: 6.zip
# 6.zip successfully uploaded to the bucket fish-detector
# Start value: 16
# End value: 18
# Invocation 6 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.04 seconds
# {'zip': '7.zip'}
# 7.zip
# ZIP file successfully created: 7.zip
# 7.zip successfully uploaded to the bucket fish-detector
# Start value: 19
# End value: 21
# Invocation 7 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.17 seconds
# {'zip': '8.zip'}
# 8.zip
# ZIP file successfully created: 8.zip
# 8.zip successfully uploaded to the bucket fish-detector
# Start value: 22
# End value: 24
# Invocation 8 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.12 seconds
# {'zip': '9.zip'}
# 9.zip
# ZIP file successfully created: 9.zip
# 9.zip successfully uploaded to the bucket fish-detector
# Start value: 25
# End value: 27
# Invocation 9 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '10.zip'}
# 10.zip
# ZIP file successfully created: 10.zip
# 10.zip successfully uploaded to the bucket fish-detector
# Start value: 28
# End value: 30
# Invocation 10 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '11.zip'}
# 11.zip
# ZIP file successfully created: 11.zip
# 11.zip successfully uploaded to the bucket fish-detector
# Start value: 31
# End value: 33
# Invocation 11 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.04 seconds
# {'zip': '12.zip'}
# 12.zip
# ZIP file successfully created: 12.zip
# 12.zip successfully uploaded to the bucket fish-detector
# Start value: 34
# End value: 36
# Invocation 12 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.04 seconds
# {'zip': '13.zip'}
# 13.zip
# ZIP file successfully created: 13.zip
# 13.zip successfully uploaded to the bucket fish-detector
# Start value: 37
# End value: 39
# Invocation 13 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.25 seconds
# {'zip': '14.zip'}
# 14.zip
# ZIP file successfully created: 14.zip
# 14.zip successfully uploaded to the bucket fish-detector
# Start value: 40
# End value: 42
# Invocation 14 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.22 seconds
# {'zip': '15.zip'}
# 15.zip
# ZIP file successfully created: 15.zip
# 15.zip successfully uploaded to the bucket fish-detector
# Start value: 43
# End value: 45
# Invocation 15 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.07 seconds
# {'zip': '16.zip'}
# 16.zip
# ZIP file successfully created: 16.zip
# 16.zip successfully uploaded to the bucket fish-detector
# Start value: 46
# End value: 48
# Invocation 16 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '17.zip'}
# 17.zip
# ZIP file successfully created: 17.zip
# 17.zip successfully uploaded to the bucket fish-detector
# Start value: 49
# End value: 51
# Invocation 17 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '18.zip'}
# 18.zip
# ZIP file successfully created: 18.zip
# 18.zip successfully uploaded to the bucket fish-detector
# Start value: 52
# End value: 54
# Invocation 18 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.25 seconds
# {'zip': '19.zip'}
# 19.zip
# ZIP file successfully created: 19.zip
# 19.zip successfully uploaded to the bucket fish-detector
# Start value: 55
# End value: 57
# Invocation 19 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '20.zip'}
# 20.zip
# ZIP file successfully created: 20.zip
# 20.zip successfully uploaded to the bucket fish-detector
# Start value: 58
# End value: 60
# Invocation 20 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '21.zip'}
# 21.zip
# ZIP file successfully created: 21.zip
# 21.zip successfully uploaded to the bucket fish-detector
# Start value: 61
# End value: 63
# Invocation 21 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.25 seconds
# {'zip': '22.zip'}
# 22.zip
# ZIP file successfully created: 22.zip
# 22.zip successfully uploaded to the bucket fish-detector
# Start value: 64
# End value: 66
# Invocation 22 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '23.zip'}
# 23.zip
# ZIP file successfully created: 23.zip
# 23.zip successfully uploaded to the bucket fish-detector
# Start value: 67
# End value: 69
# Invocation 23 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.15 seconds
# {'zip': '24.zip'}
# 24.zip
# ZIP file successfully created: 24.zip
# 24.zip successfully uploaded to the bucket fish-detector
# Start value: 70
# End value: 72
# Invocation 24 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '25.zip'}
# 25.zip
# ZIP file successfully created: 25.zip
# 25.zip successfully uploaded to the bucket fish-detector
# Start value: 73
# End value: 75
# Invocation 25 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 44.55 seconds
# {'zip': '26.zip'}
# 26.zip
# ZIP file successfully created: 26.zip
# 26.zip successfully uploaded to the bucket fish-detector
# Start value: 76
# End value: 78
# Invocation 26 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.55 seconds
# {'zip': '27.zip'}
# 27.zip
# ZIP file successfully created: 27.zip
# 27.zip successfully uploaded to the bucket fish-detector
# Start value: 79
# End value: 81
# Invocation 27 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.14 seconds
# {'zip': '28.zip'}
# 28.zip
# ZIP file successfully created: 28.zip
# 28.zip successfully uploaded to the bucket fish-detector
# Start value: 82
# End value: 84
# Invocation 28 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.35 seconds
# {'zip': '29.zip'}
# 29.zip
# ZIP file successfully created: 29.zip
# 29.zip successfully uploaded to the bucket fish-detector
# Start value: 85
# End value: 87
# Invocation 29 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.04 seconds
# {'zip': '30.zip'}
# 30.zip
# ZIP file successfully created: 30.zip
# 30.zip successfully uploaded to the bucket fish-detector
# Start value: 88
# End value: 90
# Invocation 30 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.15 seconds
# {'zip': '31.zip'}
# 31.zip
# ZIP file successfully created: 31.zip
# 31.zip successfully uploaded to the bucket fish-detector
# Start value: 91
# End value: 93
# Invocation 31 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.25 seconds
# {'zip': '32.zip'}
# 32.zip
# ZIP file successfully created: 32.zip
# 32.zip successfully uploaded to the bucket fish-detector
# Start value: 94
# End value: 96
# Invocation 32 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.07 seconds
# {'zip': '33.zip'}
# 33.zip
# ZIP file successfully created: 33.zip
# 33.zip successfully uploaded to the bucket fish-detector
# Start value: 97
# End value: 99
# Invocation 33 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.31 seconds
# {'zip': '34.zip'}
# 34.zip
# ZIP file successfully created: 34.zip
# 34.zip successfully uploaded to the bucket fish-detector
# Start value: 100
# End value: 102
# Invocation 34 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.04 seconds
# {'zip': '35.zip'}
# 35.zip
# ZIP file successfully created: 35.zip
# 35.zip successfully uploaded to the bucket fish-detector
# Start value: 103
# End value: 105
# Invocation 35 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.35 seconds
# {'zip': '36.zip'}
# 36.zip
# ZIP file successfully created: 36.zip
# 36.zip successfully uploaded to the bucket fish-detector
# Start value: 106
# End value: 108
# Invocation 36 to the service
# https://inference-walton.cloud.imagine-ai.eu/job/fish-detector-zip-3
#
# 201
#
# Total time of service launch: 6.35 seconds
# Total time of the execution process: 261.17 seconds
